# %% [markdown]
# ### Entropy

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
## "discrete" entropy

# generate data
N = 1000
numbers = np.ceil( 8*np.random.rand(N)**2 )
numbers[numbers==7] = 4
plt.plot(numbers,'o')

# %%
## "discrete" entropy

# generate data
N = 1000
numbers = np.ceil( 8*np.random.rand(N)**2 )


# get counts and probabilities
u = np.unique(numbers)
probs = np.zeros(len(u))

for ui in range(len(u)):
    probs[ui] = sum(numbers==u[ui]) / N

    
# compute entropy
entropee = -sum( probs*np.log2(probs+np.finfo(float).eps) )


# plot
plt.bar(u,probs)
plt.title('Entropy = %g'%entropee)
plt.xlabel('Data value')
plt.ylabel('Probability')
plt.show()

# %%
## for random variables

# create Brownian noise
N = 1123

## TODO Create Browny Noise which should be a cumsum of a random +1 or -1

fig,ax = plt.subplots(2,1,figsize=(4,6))
ax[0].plot(brownnoise)
ax[0].set_xlabel('Data index')
ax[0].set_ylabel('Data value')
ax[0].set_title('Brownian noise')

ax[1].hist(brownnoise,30)
ax[1].set_xlabel('Data value')
ax[1].set_ylabel('Counts')
plt.show()

# %% [markdown]
# brownnoise = np.cumsum( np.sign(np.random.randn(N)) )
#
# ![](./../../../img/2023-10-24-12-29-56.png)

# %%
### now compute entropy
# number of bins
nbins = 50

# bin the data and convert to probability
nPerBin,bins = np.histogram(brownnoise,nbins)
probs = nPerBin / sum(nPerBin)

# TODO Calculate the entropy knwoing that entropy = - Sum (p_i * log2(p_i))
# Include the closest number to zero: +np.finfo(float).eps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\github\testing\mappings-cli\utils\data-science-cli\problems\probability_intuition\descriptive_statistics\entropy.ipynb Cell 6 line <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/github/testing/mappings-cli/utils/data-science-cli/problems/probability_intuition/descriptive_statistics/entropy.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> nbins = 50
#       <a href='vscode-notebook-cell:/c%3A/github/testing/mappings-cli/utils/data-science-cli/problems/probability_intuition/descriptive_statistics/entropy.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> # bin the data and convert to probability
# ----> <a href='vscode-notebook-cell:/c%3A/github/testing/mappings-cli/utils/data-science-cli/problems/probability_intuition/descriptive_statistics/entropy.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> nPerBin,bins = np.histogram(brownnoise,nbins)
#       <a href='vscode-notebook-cell:/c%3A/github/testing/mappings-cli/utils/data-science-cli/problems/probability_intuition/descriptive_statistics/entropy.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> probs = nPerBin / sum(nPerBin)
#
# NameError: name 'np' is not defined

# %% [markdown]
# entro = -sum( probs*np.log2(probs+np.finfo(float).eps) )
#
# print('Entropy = %g'%entro)
#
#
# >> Entropy = 5.28196
